# %%
import pandas as pd
import numpy as np

# %%
jamesbond=pd.read_csv(r"C:\Users\nihar\Downloads\jamesbond.csv")
jamesbond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
jamesbond=pd.read_csv(r"C:\Users\nihar\Downloads\jamesbond.csv",usecols=["Director"]).squeeze("columns")
jamesbond
# Out:
# 0          Terence Young
# 1          Terence Young
# 2           Guy Hamilton
# 3          Terence Young
# 4             Ken Hughes
# 5          Lewis Gilbert
# 6          Peter R. Hunt
# 7           Guy Hamilton
# 8           Guy Hamilton
# 9           Guy Hamilton
# 10         Lewis Gilbert
# 11         Lewis Gilbert
# 12             John Glen
# 13        Irvin Kershner
# 14             John Glen
# 15             John Glen
# 16             John Glen
# 17             John Glen
# 18       Martin Campbell
# 19    Roger Spottiswoode
# 20         Michael Apted
# 21          Lee Tamahori
# 22       Martin Campbell
# 23          Marc Forster
# 24            Sam Mendes
# 25            Sam Mendes
# 26    Cary Joji Fukunaga
# Name: Director, dtype: object

# %%
jamesbond.head()
# Out:
# 0    Terence Young
# 1    Terence Young
# 2     Guy Hamilton
# 3    Terence Young
# 4       Ken Hughes
# Name: Director, dtype: object

# %%
jamesbond=pd.read_csv(r"C:\Users\nihar\Downloads\jamesbond.csv")
jamesbond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
jamesbond.sort_index()
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
jamesbond.sort_index(ascending=False)
# Out:
#                                Film  Year           Actor            Director  \
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# ...

# %%
jamesbond.sort_index(ascending=False)
# Out:
#                                Film  Year           Actor            Director  \
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# ...

# %%
jamesbond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
jamesbond.sort_values("Actor",ascending=False)
# Out:
#                                Film  Year           Actor            Director  \
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# ...

# %%
jamesbond=pd.read_csv(r"C:\Users\nihar\Downloads\jamesbond.csv",index_col="Actor")
jamesbond
# Out:
#                                            Film  Year            Director  \
# Actor
# Sean Connery                             Dr. No  1962       Terence Young
# Sean Connery              From Russia with Love  1963       Terence Young
# Sean Connery                         Goldfinger  1964        Guy Hamilton
# Sean Connery                        Thunderball  1965       Terence Young
# David Niven                       Casino Royale  1967          Ken Hughes
# Sean Connery                You Only Live Twice  1967       Lewis Gilbert
# George Lazenby  On Her Majesty's Secret Service  1969       Peter R. Hunt
# Sean Connery               Diamonds Are Forever  1971        Guy Hamilton
# Roger Moore                    Live and Let Die  1973        Guy Hamilton
# Roger Moore         The Man with the Golden Gun  1974        Guy Hamilton
# Roger Moore                The Spy Who Loved Me  1977       Lewis Gilbert
# Roger Moore                           Moonraker  1979       Lewis Gilbert
# ...

# %%
#To add a new column to the existing dataset

# %%
jamesbond["Award"]="Oscars"
jamesbond
# Out:
#                                            Film  Year            Director  \
# Actor
# Sean Connery                             Dr. No  1962       Terence Young
# Sean Connery              From Russia with Love  1963       Terence Young
# Sean Connery                         Goldfinger  1964        Guy Hamilton
# Sean Connery                        Thunderball  1965       Terence Young
