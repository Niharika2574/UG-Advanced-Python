# %%
import pandas as pd
import numpy as np

# %%
nba=pd.read_csv(r"C:\Users\nihar\Downloads\nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
#Add a new column

# %%
nba["nba"]=""
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary nba   My_Name
# 0        Villanova   4556983.0      Niharika
# 1       Fenerbahce  18700000.0      Niharika
# ...

# %%
#Reduce salary by 5%

# %%
nba["Red_Salary"]=nba["Salary"]*5/100
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary nba   My_Name  Red_Salary
# 0        Villanova   4556983.0      Niharika   227849.15
# ...

# %%
nba["New_Red_Salary"]=nba["Salary"]-nba["Red_Salary"]
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary nba   My_Name  Red_Salary  New_Red_Salary
# 0        Villanova   4556983.0      Niharika   227849.15      4329133.85
# ...

# %%
#Use dropna to remove rows with NaN

# %%
nba.dropna(axis=0,how="any")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary nba   My_Name  Red_Salary  New_Red_Salary
# 0        Villanova   4556983.0      Niharika   227849.15      4329133.85
# ...

# %%
#Convert height in centimetre

# %%
nba[["Feet","Inch"]]=nba["Height"].str.split("-",expand=True)
nba[["Feet","Inch"]]
# Out:
#     Feet Inch
# 0      6    7
# 1      6    5
# 2      6    5
# 3      6   10
# 4      6   10
# ..   ...  ...
# 587    6    3
# 588    6    4
# 589    6   10
# 590    6    5
# 591  NaN  NaN
#
# [592 rows x 2 columns]

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary nba   My_Name  Red_Salary  New_Red_Salary Feet  \
# 0        Villanova   4556983.0      Niharika   227849.15      4329133.85    6
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            591 non-null    object
#  1   Team            591 non-null    object
#  2   Position        584 non-null    object
#  3   Height          585 non-null    object
#  4   Weight          584 non-null    float64
#  5   College         578 non-null    object
#  6   Salary          488 non-null    float64
#  7   nba             592 non-null    object
#  8   My_Name         592 non-null    object
#  9   Red_Salary      488 non-null    float64
#  10  New_Red_Salary  488 non-null    float64
#  11  Feet            585 non-null    object
#  12  Inch            585 non-null    object
# dtypes: float64(4), object(9)
# memory usage: 60.3+ KB

# %%
nba.Feet.astype("float")
# Out:
# 0      6.0
# 1      6.0
# 2      6.0
# 3      6.0
# 4      6.0
#       ...
# 587    6.0
# 588    6.0
# 589    6.0
# 590    6.0
# 591    NaN
# Name: Feet, Length: 592, dtype: float64

# %%
nba.Feet=nba.Feet.astype("float")
nba.Feet
# Out:
# 0      6.0
# 1      6.0
# 2      6.0
# 3      6.0
# 4      6.0
#       ...
# 587    6.0
# 588    6.0
# 589    6.0
# 590    6.0
# 591    NaN
# Name: Feet, Length: 592, dtype: float64

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            591 non-null    object
#  1   Team            591 non-null    object
#  2   Position        584 non-null    object
#  3   Height          585 non-null    object
#  4   Weight          584 non-null    float64
#  5   College         578 non-null    object
#  6   Salary          488 non-null    float64
#  7   nba             592 non-null    object
#  8   My_Name         592 non-null    object
#  9   Red_Salary      488 non-null    float64
#  10  New_Red_Salary  488 non-null    float64
#  11  Feet            585 non-null    float64
#  12  Inch            585 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 60.3+ KB

# %%
nba[["Feet","Inch"]]=nba[["Feet","Inch"]].apply(pd.to_numeric)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            591 non-null    object
#  1   Team            591 non-null    object
#  2   Position        584 non-null    object
#  3   Height          585 non-null    object
#  4   Weight          584 non-null    float64
#  5   College         578 non-null    object
#  6   Salary          488 non-null    float64
#  7   nba             592 non-null    object
#  8   My_Name         592 non-null    object
#  9   Red_Salary      488 non-null    float64
#  10  New_Red_Salary  488 non-null    float64
#  11  Feet            585 non-null    float64
#  12  Inch            585 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 60.3+ KB

# %%
nba["Feet"]*30.48+nba["Inch"]*2.54
# Out:
# 0      200.66
# 1      195.58
# 2      195.58
# 3      208.28
# 4      208.28
#         ...
# 587    190.50
# 588    193.04
# 589    208.28
# 590    195.58
# 591       NaN
# Length: 592, dtype: float64

# %%
nba["Height_in_centimetre"]=nba["Feet"]*30.48+nba["Inch"]*2.54
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary nba   My_Name  Red_Salary  New_Red_Salary  \
# 0        Villanova   4556983.0      Niharika   227849.15      4329133.85
# ...

# %%
#fake

# %%
#fake

# %%
#fake

# %%
nba["Salary"]>400000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 587     True
# 588     True
# 589    False
# 590     True
# 591    False
# Name: Salary, Length: 592, dtype: bool
