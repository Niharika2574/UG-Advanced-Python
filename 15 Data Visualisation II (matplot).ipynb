# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ibm=pd.read_csv(r"C:\Users\nihar\Downloads\ibm.csv")
ibm
# Out:
#              Date       Open       High        Low      Close        Volume
# 0      1962-01-02    5.04610    5.04610    4.98716    4.98716  5.935630e+05
# 1      1962-01-03    4.98716    5.03292    4.98716    5.03292  4.451750e+05
# 2      1962-01-04    5.03292    5.03292    4.98052    4.98052  3.995136e+05
# 3      1962-01-05    4.97389    4.97389    4.87511    4.88166  5.593215e+05
# 4      1962-01-08    4.88166    4.88166    4.75059    4.78972  8.332738e+05
# ...           ...        ...        ...        ...        ...           ...
# 15541  2023-10-05  140.90000  141.70000  140.19000  141.52000  3.223910e+06
# 15542  2023-10-06  141.40000  142.94000  140.11000  142.03000  3.511347e+06
# 15543  2023-10-09  142.30000  142.40000  140.68000  142.20000  2.354396e+06
# 15544  2023-10-10  142.60000  143.41500  141.72000  142.11000  3.015784e+06
# 15545  2023-10-11  142.51000  143.34000  142.14000  143.23000  2.511459e+06
#
# [15546 rows x 6 columns]

# %%
average_stock_price=ibm["Close"].mean()

# %%
def rank_performance(stock_price):
    if stock_price >= average_stock_price:
        return "Above Average"
        
    return "Below Average"

plt.style.use("seaborn-v0_8-pastel")
ibm["Close"].apply(rank_performance).value_counts().plot(kind="pie",legend=True)
# Out:
# <Axes: ylabel='count'>

# %%
piece=pd.read_csv(r"C:\Users\nihar\Downloads\Piece_Dim.csv")
piece
# Out:
#     Item_No  Length  Width  Height Operator
# 0    Item-1  102.67  49.53   19.69     Op-1
# 1    Item-2  102.50  51.42   19.63     Op-1
# 2    Item-3   95.37  52.25   21.51     Op-1
# 3    Item-4   94.77  49.24   18.60     Op-1
# 4    Item-5  104.26  47.90   19.46     Op-1
# 5    Item-6  105.18  49.39   20.36     Op-1
# 6    Item-7   97.35  48.05   20.22     Op-1
# 7    Item-8   99.35  44.59   21.03     Op-1
# 8    Item-9   90.62  47.29   19.78     Op-1
# 9   Item-10   97.22  52.14   20.71     Op-1
# 10  Item-11  100.00  54.76   20.62     Op-1
# 11  Item-12   97.23  48.26   19.51     Op-1
# 12  Item-13  105.72  50.04   20.06     Op-1
# 13  Item-14   89.82  45.98   20.30     Op-1
# 14  Item-15   99.17  53.54   20.25     Op-1
# 15  Item-16   95.51  45.36   20.52     Op-1
# 16  Item-17  107.69  48.18   19.33     Op-1
# 17  Item-18  106.83  50.81   19.12     Op-1
# 18  Item-19   98.73  55.76   19.37     Op-1
# 19  Item-20   94.31  48.74   18.80     Op-1
# ...

# %%
piece.head()
# Out:
#   Item_No  Length  Width  Height Operator
# 0  Item-1  102.67  49.53   19.69     Op-1
# 1  Item-2  102.50  51.42   19.63     Op-1
# 2  Item-3   95.37  52.25   21.51     Op-1
# 3  Item-4   94.77  49.24   18.60     Op-1
# 4  Item-5  104.26  47.90   19.46     Op-1

# %%
piece.describe()
# Out:
#            Length      Width     Height
# count   50.000000  50.000000  50.000000
# mean   100.128800  49.461400  20.014000
# std      5.075593   2.615639   1.074069
# min     89.820000  44.460000  17.370000
# 25%     95.675000  48.105000  19.375000
# 50%     99.830000  49.315000  19.930000
# 75%    104.402500  50.780000  20.595000
# max    110.540000  55.760000  23.110000

# %%
plt.hist(piece["Length"]) #takes 10 bins by default
# Out:
# (array([2., 3., 9., 6., 6., 7., 4., 6., 5., 2.]),
#  array([ 89.82 ,  91.892,  93.964,  96.036,  98.108, 100.18 , 102.252,
#         104.324, 106.396, 108.468, 110.54 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(piece["Length"],bins=15)
plt.show()

# %%
plt.hist(piece['Length'], bins=15, color='Red')             
plt.xlabel("Length in mm.")
plt.ylabel("Count")
plt.title("Histogram of Piece Length")
plt.show()

# %%
plt.style.use("dark_background")
plt.boxplot(piece['Length'])
plt.show()

# %%
op1 = piece[piece['Operator']=='Op-1']
op2 = piece[piece['Operator']=='Op-2']

# %%
op1
# Out:
#     Item_No  Length  Width  Height Operator
# 0    Item-1  102.67  49.53   19.69     Op-1
# 1    Item-2  102.50  51.42   19.63     Op-1
# 2    Item-3   95.37  52.25   21.51     Op-1
# 3    Item-4   94.77  49.24   18.60     Op-1
# 4    Item-5  104.26  47.90   19.46     Op-1
# 5    Item-6  105.18  49.39   20.36     Op-1
# 6    Item-7   97.35  48.05   20.22     Op-1
# 7    Item-8   99.35  44.59   21.03     Op-1
# 8    Item-9   90.62  47.29   19.78     Op-1
# 9   Item-10   97.22  52.14   20.71     Op-1
# 10  Item-11  100.00  54.76   20.62     Op-1
# 11  Item-12   97.23  48.26   19.51     Op-1
# 12  Item-13  105.72  50.04   20.06     Op-1
# 13  Item-14   89.82  45.98   20.30     Op-1
# 14  Item-15   99.17  53.54   20.25     Op-1
# 15  Item-16   95.51  45.36   20.52     Op-1
# 16  Item-17  107.69  48.18   19.33     Op-1
# 17  Item-18  106.83  50.81   19.12     Op-1
# 18  Item-19   98.73  55.76   19.37     Op-1
# 19  Item-20   94.31  48.74   18.80     Op-1
# ...

# %%
op2.head()
# Out:
#     Item_No  Length  Width  Height Operator
# 25  Item-26   95.69  49.48   17.37     Op-2
# 26  Item-27  105.88  49.53   18.70     Op-2
# 27  Item-28  101.68  52.79   19.42     Op-2
# 28  Item-29   93.54  51.05   19.29     Op-2
# 29  Item-30   99.66  48.40   20.64     Op-2

# %%
plt.style.use('seaborn-v0_8-deep')
plt.boxplot([op1['Length'], op2['Length']])
plt.show()

# %%
plt.boxplot([op1['Length'], op2['Length']], notch=True)
plt.xlabel('Operator')
plt.ylabel('Length in mm')
plt.title('Box Plot By Operator')
plt.show()

# %%
plt.plot(piece['Length'])
plt.show()

# %%
plt.plot(piece['Length'])
mean_l = piece['Length'].mean()
sd_l = piece['Length'].std()
plt.axhline(y=mean_l, color='red', linestyle='-')
plt.axhline(y=(mean_l + 3*sd_l), color='red', linestyle='--')
plt.axhline(y=(mean_l - 3*sd_l), color='red', linestyle='--')
plt.show()

# %%
plt.figure(figsize=(10,3)) 
plt.plot(piece['Length'])
mean_l = piece['Length'].mean()
sd_l = piece['Length'].std()
plt.axhline(y=mean_l, color='red', linestyle='-')
plt.axhline(y=(mean_l + 3*sd_l), color='red', linestyle='--')
plt.axhline(y=(mean_l - 3*sd_l), color='red', linestyle='--')
plt.show()

# %%
plt.scatter(piece['Length'], piece['Width'])

# %%
plt.scatter(data=piece, x= 'Length', y='Width', marker='v')

# %%
opers = ['Operator 1', 'Operator 2', 'Operator3']
pieces = [50, 35, 70]
plt.bar(opers, pieces)
plt.show()

# %%
lowl = piece[piece['Length']<95]['Length'].count()           
medl = piece[(piece['Length']>=95) & (piece['Length']<=105)]['Length'].count()
higl = piece[piece['Length']>105]['Length'].count()

sizel = [lowl, medl, higl]
groupl = ['< 95', 'Bewteen 95 and 105', '>105']
plt.bar(groupl, sizel)
plt.show()

# %%
plt.hist(piece['Length'])
plt.show()

# %%
sns.histplot(data=piece, x='Length', bins=10)
plt.title('Histogram')
plt.show()

# %%
#

# %%
#

# %%
#

# %%
#

# %%
#
